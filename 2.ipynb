# %%
import csv
import re
import time
import cProfile
from collections import defaultdict, deque
import networkx as nx

def compute_scc_bounds(graph):
    """在 SCC 图上迭代计算 alpha 和 omega 值。"""
    if not isinstance(graph, nx.DiGraph) or not graph.nodes:
        return None

    # 1. 获取所有 SCC
    sccs = list(nx.strongly_connected_components(graph))

    # 2. 从 SCC 创建一个新图
    scc_graph = nx.DiGraph()
    scc_weights = {}
    scc_node_map = {}

    for i, scc in enumerate(sccs):
        scc_node = f"SCC_{i}"
        scc_graph.add_node(scc_node)
        scc_weights[scc_node] = len(scc)
        for node in scc:
            scc_node_map[node] = scc_node

    # 在 SCC 之间添加边
    for u in graph.nodes:
        for v in graph.neighbors(u):
            if scc_node_map[u] != scc_node_map[v]:
                scc_graph.add_edge(scc_node_map[u], scc_node_map[v])

    # 3. 初始化所有 SCC 节点的 alpha 和 omega
    scc_bounds = {}
    for scc_node in scc_graph.nodes:
        scc_bounds[scc_node] = (scc_weights[scc_node], scc_weights[scc_node])

    # 4. 反向拓扑排序（处理循环）
    remaining_nodes = set(scc_graph.nodes) #考虑SCC图中的所有节点进行拓扑排序
    reverse_topological_order = []
    if len(remaining_nodes) > 0:
        try:
            reverse_topological_order = list(nx.topological_sort(scc_graph.reverse().subgraph(remaining_nodes)))
        except nx.NetworkXUnfeasible:
            print("Warning: SCC 图中检测到循环。使用启发式排序。")
            reverse_topological_order = sorted(remaining_nodes, key=lambda node: scc_graph.degree(node), reverse=True)

    # 5. 迭代并更新 alpha 和 omega
    for scc_node in reversed(reverse_topological_order): #反向迭代
        for neighbor in scc_graph.neighbors(scc_node):
            scc_bounds[scc_node] = (max(scc_bounds[scc_node][0], scc_bounds[neighbor][0]),
                                    scc_bounds[scc_node][1] + scc_bounds[neighbor][1])

    # 6. 将边界分配给原始节点
    node_bounds = {}
    for node in graph.nodes:
        scc_node = scc_node_map[node]
        node_bounds[node] = scc_bounds[scc_node]

    return node_bounds


def neighborhood_lower_bound(graph):
    nodes = list(graph.nodes())
    n = len(nodes)
    lower_bounds = {}
    scc_bounds = compute_scc_bounds(graph)
    if scc_bounds is None:
        print("Error computing SCC bounds. Returning empty dictionary.")
        return {}
    reachable_nodes_dict = {node: bounds[0] for node, bounds in scc_bounds.items()}
    k = 2
    max_iterations = 10
    
    neighbors_dict = {node: list(graph.neighbors(node)) for node in nodes}
    
    Y = {}
    S_un = {} # 将列表改为字典
    nVisited = {}
    finished = {}

    while k <= max_iterations:
        for s in nodes:
            degree_s = graph.out_degree(s)
            Y[(k - 1, s)] = degree_s
            S_un[s] = degree_s # 使用节点名称（字符串）作为键
            nVisited[s] = degree_s + 1
            finished[s] = False

        nFinished = 0
        while nFinished < n:
            for s in nodes:
                if finished[s]:
                    continue
                r_v = reachable_nodes_dict[s]
                if k == 2:
                    Y[(k, s)] = sum(Y[(k - 1, w)] for w in neighbors_dict[s]) - graph.out_degree(s)
                elif k > 2:
                    Y[(k, s)] = sum(Y[(k - 1, w)] for w in neighbors_dict[s]) - Y.get((k - 2, s), 0) * (graph.out_degree(s) - 1)
                else:
                    Y[(k, s)] = 0
                nVisited[s] += Y.get((k - 1, s), 0)
                if nVisited[s] < r_v:
                    S_un[s] = S_un[s] + k * Y.get((k - 1, s), 0) # 使用节点名称作为键
                else:
                    S_un[s] = S_un[s] + k * (r_v - (nVisited[s] - Y.get((k - 1, s), 0))) # 使用节点名称作为键
                    nFinished += 1
                    finished[s] = True
        k += 1
    for v in nodes:
        r_v = reachable_nodes_dict[v]
        #print(S_un[v])
        #print(n)
        #print(r_v)
        #print('#####################')
        lower_bounds[v] = (n - 1) * S_un[v] / ((r_v - 1) ** 2) if r_v > 1 else 0
    return lower_bounds

def create_mention_graph_with_centrality(filepath):
    start_time = time.time()
    edge_weights = defaultdict(int)
    def process_chunk(chunk):
        for row in chunk:
            try:
                timestamp, user, tweet_text = row
                mentions = re.findall(r'@([a-zA-Z0-9_]+)', tweet_text)
                for mention in mentions:
                    edge_weights[(user, mention)] += 1
            except (ValueError, IndexError) as e:
                print(f"Error processing row: {row}. Skipping. Error: {e}")
    chunk_size = 100000
    current_chunk = []
    with open(filepath, 'r', encoding='utf-8') as file:
        reader = csv.reader(file, delimiter='\t')
        for row in reader:
            current_chunk.append(row)
            if len(current_chunk) == chunk_size:
                process_chunk(current_chunk)
                current_chunk = []
    if current_chunk:
        process_chunk(current_chunk)
    G = nx.DiGraph()
    for (u, v), weight in edge_weights.items():
        G.add_edge(u, v, weight=weight)
    print(f"Graph created with {G.number_of_nodes()} nodes and {G.number_of_edges()} edges.")
    print("Calculating centrality...")
    lower_bounds = neighborhood_lower_bound(G)
    nx.set_node_attributes(G, lower_bounds, 'lower_centrality')
    end_time = time.time()
    total_time = end_time - start_time
    print(f"\nTotal time taken: {total_time:.4f} seconds")
    sorted_centralities = sorted(
        nx.get_node_attributes(G, 'lower_centrality').items(),
        key=lambda x: x[1],
        reverse=True
    )
    print("\nTop 10 nodes by lower centrality bound:")
    for node, centrality in sorted_centralities[:100]:
        print(f"Node: {node}, Lower Centrality: {centrality:.10f}")
    return G

if __name__ == "__main__":
    filepath = "twitter-small.tsv"  # Replace with your file path
    print("Creating graph...")
    cProfile.run('create_mention_graph_with_centrality("twitter-small.tsv")')
# Out:
# Creating graph...
# Graph created with 94861 nodes and 155574 edges.
# Calculating centrality...
#
# Total time taken: 60.7947 seconds
#
# Top 10 nodes by lower centrality bound:
# Node: tolisv, Lower Centrality: 260865.0000000000
# Node: nishajl, Lower Centrality: 260865.0000000000
# Node: karkaremtg, Lower Centrality: 260865.0000000000
# Node: mrmwrites, Lower Centrality: 260865.0000000000
# Node: wanda_g, Lower Centrality: 260865.0000000000
# Node: mineralrich, Lower Centrality: 260865.0000000000
# Node: joeyawesome, Lower Centrality: 260865.0000000000
# Node: cruzado, Lower Centrality: 260865.0000000000
# Node: celestinechua, Lower Centrality: 260865.0000000000
# Node: georgia_mcbride, Lower Centrality: 260865.0000000000
# Node: joel22882, Lower Centrality: 260865.0000000000
# Node: sharifitness, Lower Centrality: 260865.0000000000
# Node: jkwleadership, Lower Centrality: 260865.0000000000
# Node: daniel_richard, Lower Centrality: 260865.0000000000
# Node: mellypea, Lower Centrality: 221340.0000000000
# Node: illsingyouasong, Lower Centrality: 221340.0000000000
# Node: missdaffy, Lower Centrality: 221340.0000000000
# Node: diretordeletras, Lower Centrality: 221340.0000000000
# Node: sirzac, Lower Centrality: 221340.0000000000
# Node: skankyfish, Lower Centrality: 183791.2500000000
# Node: greenteagirl, Lower Centrality: 130432.5000000000
# Node: kat2222, Lower Centrality: 130432.5000000000
# Node: strongsarah, Lower Centrality: 130432.5000000000
# Node: streetwise_it, Lower Centrality: 130432.5000000000
# Node: dianawinkley, Lower Centrality: 130432.5000000000
# Node: mediaamericac2c, Lower Centrality: 130432.5000000000
# Node: janemaurer, Lower Centrality: 126480.0000000000
# Node: petmayorcontest, Lower Centrality: 94860.0000000000
# Node: midnightmovie73, Lower Centrality: 94860.0000000000
# Node: mishikraz, Lower Centrality: 94860.0000000000
# Node: darlingbuds, Lower Centrality: 94860.0000000000
# Node: eriol78, Lower Centrality: 94860.0000000000
# Node: knowledgenode, Lower Centrality: 94860.0000000000
# Node: tessmck, Lower Centrality: 94860.0000000000
# Node: alextronic, Lower Centrality: 94860.0000000000
# Node: shtfck, Lower Centrality: 94860.0000000000
# Node: davidswinney, Lower Centrality: 94860.0000000000
# Node: jordanm11, Lower Centrality: 94860.0000000000
# Node: allyclark, Lower Centrality: 94860.0000000000
# Node: gloreebe88, Lower Centrality: 94860.0000000000
# Node: rce77, Lower Centrality: 94860.0000000000
# Node: northcentralcol, Lower Centrality: 94860.0000000000
# Node: sunrayswench, Lower Centrality: 94860.0000000000
# Node: longhairgreg, Lower Centrality: 94860.0000000000
# Node: melissa_dw, Lower Centrality: 94860.0000000000
# Node: bemyinsured, Lower Centrality: 94860.0000000000
# Node: anecat, Lower Centrality: 94860.0000000000
# Node: mksmither, Lower Centrality: 94860.0000000000
# Node: dealtaker, Lower Centrality: 94860.0000000000
# Node: richburroughs, Lower Centrality: 94860.0000000000
# Node: dr_mike, Lower Centrality: 94860.0000000000
# Node: hambers, Lower Centrality: 94860.0000000000
# Node: jinzilla20, Lower Centrality: 94860.0000000000
# Node: gyt, Lower Centrality: 94860.0000000000
# Node: lipsticklaundry, Lower Centrality: 94860.0000000000
# Node: salisburydowns, Lower Centrality: 94860.0000000000
# Node: funkyblueame, Lower Centrality: 94860.0000000000
# Node: transniper, Lower Centrality: 94860.0000000000
# Node: sharonandalex, Lower Centrality: 94860.0000000000
# Node: guestblogme, Lower Centrality: 94860.0000000000
# Node: bonnibelle, Lower Centrality: 94860.0000000000
# Node: siskita, Lower Centrality: 94860.0000000000
# Node: b_age, Lower Centrality: 94860.0000000000
# Node: zunaid, Lower Centrality: 94860.0000000000
# Node: yuvalararat, Lower Centrality: 94860.0000000000
# Node: enochchoi, Lower Centrality: 94860.0000000000
# Node: lynnekelly, Lower Centrality: 94860.0000000000
# Node: pageoneresults, Lower Centrality: 94860.0000000000
# Node: pattirahn, Lower Centrality: 94860.0000000000
# Node: toddkraemer, Lower Centrality: 94860.0000000000
# Node: cwunch, Lower Centrality: 94860.0000000000
# Node: mysticstar, Lower Centrality: 94860.0000000000
# Node: averyhawk, Lower Centrality: 94860.0000000000
# Node: iambuddelt, Lower Centrality: 94860.0000000000
# Node: cheriwilliams, Lower Centrality: 94860.0000000000
# Node: evilgrrl, Lower Centrality: 94860.0000000000
# Node: charlesthomas, Lower Centrality: 94860.0000000000
# Node: einzunza, Lower Centrality: 94860.0000000000
# Node: kdash471, Lower Centrality: 94860.0000000000
# Node: naraku009, Lower Centrality: 94860.0000000000
# Node: kperry4wits, Lower Centrality: 94860.0000000000
# Node: superhose, Lower Centrality: 77073.7500000000
# Node: moseslake, Lower Centrality: 77073.7500000000
# Node: seanmalarkey, Lower Centrality: 53121.6000000000
# Node: luciferskylarke, Lower Centrality: 53121.6000000000
# Node: arpit105, Lower Centrality: 47430.0000000000
# Node: happymalesingle, Lower Centrality: 47430.0000000000
# Node: barneyausten, Lower Centrality: 47430.0000000000
# Node: torontogreen, Lower Centrality: 47430.0000000000
# Node: makakman, Lower Centrality: 47430.0000000000
# Node: jaybird76, Lower Centrality: 47430.0000000000
# Node: melvinferrer, Lower Centrality: 47430.0000000000
# Node: jnnabyrd, Lower Centrality: 47430.0000000000
# Node: donshapiro1, Lower Centrality: 47430.0000000000
# Node: josie_barnes, Lower Centrality: 47430.0000000000
# Node: soundstheway, Lower Centrality: 47430.0000000000
# Node: manyas, Lower Centrality: 47430.0000000000
# Node: gtiadvisors, Lower Centrality: 47430.0000000000
# Node: thomasmcauley, Lower Centrality: 47430.0000000000
# Node: mykitchenstore, Lower Centrality: 47430.0000000000
#          125024400 function calls (124929538 primitive calls) in 60.855 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#  48926240    7.059    0.000    7.059    0.000 2207371157.py:100(<genexpr>)
#         1    0.093    0.093   60.850   60.850 2207371157.py:120(create_mention_graph_with_centrality)
#         1    0.036    0.036    0.067    0.067 2207371157.py:123(process_chunk)
#     94861    0.003    0.000    0.003    0.000 2207371157.py:155(<lambda>)
#         1   41.651   41.651   60.126   60.126 2207371157.py:64(neighborhood_lower_bound)
#         1    0.008    0.008    0.008    0.008 2207371157.py:72(<dictcomp>)
#         1    0.039    0.039    0.053    0.053 2207371157.py:76(<dictcomp>)
#         1    0.162    0.162    2.569    2.569 2207371157.py:8(compute_scc_bounds)
#   6115780    0.695    0.000    0.695    0.000 2207371157.py:98(<genexpr>)
#         1    0.000    0.000    0.000    0.000 <class 'networkx.utils.decorators.argmap'> compilation 4:1(argmap_strongly_connected_components_1)
#     93116    0.012    0.000    0.043    0.000 <frozen _collections_abc>:778(__contains__)
#         2    0.000    0.000    0.000    0.000 <frozen _collections_abc>:790(items)
#         2    0.000    0.000    0.000    0.000 <frozen _collections_abc>:812(__init__)
#    187979    0.027    0.000    0.060    0.000 <frozen _collections_abc>:859(__iter__)
#         1    0.000    0.000    0.000    0.000 <frozen codecs>:260(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen codecs>:309(__init__)
#       711    0.000    0.000    0.002    0.000 <frozen codecs>:319(decode)
#         1    0.005    0.005   60.855   60.855 <string>:1(<module>)
#     39940    0.007    0.000    0.031    0.000 __init__.py:208(findall)
#     39940    0.006    0.000    0.008    0.000 __init__.py:272(_compile)
#         3    0.000    0.000    0.000    0.000 backends.py:409(__call__)
#    222220    0.119    0.000    0.548    0.000 copy.py:128(deepcopy)
#    222220    0.047    0.000    0.335    0.000 copy.py:227(_deepcopy_dict)
#    222220    0.058    0.000    0.072    0.000 copy.py:243(_keep_alive)
#    279349    0.018    0.000    0.018    0.000 coreviews.py:267(__init__)
#    186232    0.045    0.000    0.350    0.000 coreviews.py:271(__len__)
#    444438    0.048    0.000    0.207    0.000 coreviews.py:272(<genexpr>)
#    279348    0.096    0.000    0.096    0.000 coreviews.py:274(__iter__)
#    666657    0.069    0.000    0.224    0.000 coreviews.py:281(<genexpr>)
#     93116    0.024    0.000    0.031    0.000 coreviews.py:283(__getitem__)
#         2    0.000    0.000    0.000    0.000 coreviews.py:296(__init__)
#         2    0.000    0.000    0.000    0.000 coreviews.py:304(__iter__)
#    186234    0.031    0.000    0.047    0.000 coreviews.py:311(<genexpr>)
#    279348    0.105    0.000    0.137    0.000 coreviews.py:313(__getitem__)
#    387309    0.088    0.000    0.156    0.000 coreviews.py:316(new_node_ok)
#    189724    0.008    0.000    0.008    0.000 coreviews.py:43(__init__)
#    189722    0.016    0.000    0.022    0.000 coreviews.py:49(__iter__)
#    189722    0.278    0.000    0.286    0.000 coreviews.py:80(__getitem__)
#        20    0.053    0.003    0.874    0.044 dag.py:166(topological_generations)
#         1    0.010    0.010    0.296    0.296 dag.py:219(<dictcomp>)
#         1    0.010    0.010    0.295    0.295 dag.py:220(<listcomp>)
#     93117    0.003    0.000    0.878    0.000 dag.py:244(topological_sort)
#         1    0.000    0.000    0.000    0.000 decorators.py:1242(inner_f)
#         1    0.000    0.000    0.000    0.000 decorators.py:86(_not_implemented_for)
#         1    0.000    0.000    0.000    0.000 digraph.py:1041(degree)
#         1    0.000    0.000    0.000    0.000 digraph.py:1085(in_degree)
#         1    0.000    0.000    0.000    0.000 digraph.py:1132(out_degree)
#         2    0.000    0.000    0.000    0.000 digraph.py:1217(is_multigraph)
#         3    0.000    0.000    0.000    0.000 digraph.py:1221(is_directed)
#         1    0.000    0.000    0.874    0.874 digraph.py:1304(reverse)
#     93117    0.023    0.000    0.175    0.000 digraph.py:1320(<genexpr>)
#    129104    0.032    0.000    0.506    0.000 digraph.py:1321(<genexpr>)
#         4    0.000    0.000    0.000    0.000 digraph.py:316(__init__)
#         1    0.000    0.000    0.000    0.000 digraph.py:364(adj)
#         5    0.000    0.000    0.000    0.000 digraph.py:37(__set__)
#         1    0.000    0.000    0.000    0.000 digraph.py:383(succ)
#     93116    0.038    0.000    0.041    0.000 digraph.py:420(add_node)
#         1    0.074    0.074    0.260    0.260 digraph.py:469(add_nodes_from)
#         5    0.000    0.000    0.000    0.000 digraph.py:63(__set__)
#    302054    0.488    0.000    0.513    0.000 digraph.py:643(add_edge)
#         1    0.087    0.087    0.614    0.614 digraph.py:713(add_edges_from)
#    375954    0.056    0.000    0.152    0.000 digraph.py:874(successors)
#         1    0.000    0.000    0.000    0.000 digraph.py:931(edges)
#    387309    0.014    0.000    0.014    0.000 filters.py:20(no_filter)
#         1    0.004    0.004    0.011    0.011 filters.py:51(__init__)
#    946005    0.061    0.000    0.061    0.000 filters.py:54(__call__)
#         1    0.000    0.000    0.000    0.000 function.py:156(freeze)
#         1    0.017    0.017    0.032    0.032 function.py:552(set_node_attributes)
#         1    0.000    0.000    0.042    0.042 function.py:652(get_node_attributes)
#         1    0.015    0.015    0.042    0.042 function.py:685(<dictcomp>)
#       8/7    0.000    0.000    0.000    0.000 functools.py:981(__get__)
#         1    0.000    0.000    0.011    0.011 graph.py:1763(subgraph)
#         1    0.000    0.000    0.035    0.035 graph.py:1869(size)
#     94862    0.008    0.000    0.032    0.000 graph.py:1905(<genexpr>)
#         1    0.000    0.000    0.035    0.035 graph.py:1912(number_of_edges)
#         1    0.000    0.000    0.000    0.000 graph.py:1964(nbunch_iter)
#     93117    0.007    0.000    0.007    0.000 graph.py:2010(bunch_iter)
#         2    0.000    0.000    0.000    0.000 graph.py:435(__iter__)
#     93117    0.012    0.000    0.055    0.000 graph.py:453(__contains__)
#    189722    0.023    0.000    0.308    0.000 graph.py:489(__getitem__)
#         5    0.000    0.000    0.000    0.000 graph.py:59(__set__)
#         2    0.000    0.000    0.000    0.000 graph.py:732(nodes)
#         1    0.000    0.000    0.000    0.000 graph.py:825(number_of_nodes)
#         1    0.000    0.000    0.000    0.000 graphviews.py:135(subgraph_view)
#    258206    0.031    0.000    0.040    0.000 graphviews.py:223(reverse_edge)
#         1    0.000    0.000    0.000    0.000 interactiveshell.py:315(_modified_open)
#         2    0.000    0.000    0.000    0.000 iostream.py:137(_event_pipe)
#         2    0.000    0.000    0.000    0.000 iostream.py:258(schedule)
#       208    0.000    0.000    0.000    0.000 iostream.py:519(_is_master_process)
#       208    0.000    0.000    0.000    0.000 iostream.py:546(_schedule_flush)
#       208    0.000    0.000    0.000    0.000 iostream.py:624(write)
#         1    0.000    0.000    0.000    0.000 reportviews.py:1056(__init__)
#         1    0.000    0.000    0.000    0.000 reportviews.py:1088(__call__)
#         2    0.000    0.000    0.000    0.000 reportviews.py:178(__init__)
#         2    0.000    0.000    0.000    0.000 reportviews.py:182(__len__)
#         7    0.000    0.000    0.000    0.000 reportviews.py:185(__iter__)
#    282838    0.039    0.000    0.048    0.000 reportviews.py:188(__getitem__)
#         1    0.000    0.000    0.000    0.000 reportviews.py:205(__call__)
#         3    0.000    0.000    0.000    0.000 reportviews.py:417(__init__)
#   8624280    2.064    0.000    3.541    0.000 reportviews.py:424(__call__)
#     94862    0.020    0.000    0.024    0.000 reportviews.py:448(__iter__)
#   8624277    1.219    0.000    1.476    0.000 reportviews.py:545(__getitem__)
#    186234    0.062    0.000    0.572    0.000 reportviews.py:575(__iter__)
#         1    0.000    0.000    0.000    0.000 reportviews.py:760(__init__)
#    129103    0.006    0.000    0.006    0.000 reportviews.py:774(<lambda>)
#         1    0.000    0.000    0.000    0.000 reportviews.py:787(__iter__)
#    129104    0.036    0.000    0.045    0.000 reportviews.py:788(<genexpr>)
#         2    0.000    0.000    0.000    0.000 socket.py:621(send)
#     93117    0.116    0.000    0.488    0.000 strongly_connected.py:15(strongly_connected_components)
#         1    0.018    0.018    0.297    0.297 strongly_connected.py:79(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 threading.py:1118(_wait_for_tstate_lock)
#         2    0.000    0.000    0.000    0.000 threading.py:1185(is_alive)
#         2    0.000    0.000    0.000    0.000 threading.py:568(is_set)
#       711    0.001    0.000    0.001    0.000 {built-in method _codecs.utf_8_decode}
#         1    0.000    0.000    0.000    0.000 {built-in method _csv.reader}
#         1    0.000    0.000   60.855   60.855 {built-in method builtins.exec}
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#    888880    0.029    0.000    0.029    0.000 {built-in method builtins.id}
#    322987    0.012    0.000    0.012    0.000 {built-in method builtins.isinstance}
# 660546/565685    0.032    0.000    0.072    0.000 {built-in method builtins.iter}
#   9262609    0.290    0.000    0.640    0.000 {built-in method builtins.len}
#    129103    0.007    0.000    0.007    0.000 {built-in method builtins.max}
#      9094    0.001    0.000    0.001    0.000 {built-in method builtins.min}
#       104    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         1    0.010    0.010    0.013    0.013 {built-in method builtins.sorted}
#   7956761    2.863    0.000   10.856    0.000 {built-in method builtins.sum}
#         1    0.000    0.000    0.000    0.000 {built-in method io.open}
#       208    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         2    0.000    0.000    0.000    0.000 {built-in method time.time}
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_io._IOBase' objects}
#       216    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#      1745    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         2    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#    139872    0.005    0.000    0.005    0.000 {method 'append' of 'list' objects}
#     93116    0.003    0.000    0.003    0.000 {method 'copy' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#     39940    0.016    0.000    0.016    0.000 {method 'findall' of 're.Pattern' objects}
#  23323805    1.757    0.000    1.757    0.000 {method 'get' of 'dict' objects}
#    315341    0.283    0.000    0.283    0.000 {method 'items' of 'dict' objects}
#     96606    0.004    0.000    0.004    0.000 {method 'pop' of 'list' objects}
#    839613    0.033    0.000    0.033    0.000 {method 'update' of 'dict' objects}
#     93116    0.009    0.000    0.009    0.000 {method 'update' of 'set' objects}
#       208    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
